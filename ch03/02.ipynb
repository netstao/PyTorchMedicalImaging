# %%
# 理解数据
1. 是否有数据
2. 有多少数据
3. 有什么样的数据
4. 数据标注

# 准备数据
1. 找到数据
2. 数据探索
3. 数据清洗
    1. 异常值处理
    2. 缺失值处理
    3. 数据偏差
    4. 数据标准化
    5. 特征选择
4. 构建数据集

# 构建模型
1. 问题拆分
2. 模型选择
3. 参数调整
4. 模型集成

# 模型评估
1. 指标选择
2. 指标自测
3. 三方离线评估
4. 线上指标评估

# 模型部署
1. 模型存储
- 最佳的模型结果保存起来，方便后续调用
2. 性能优化
3. 工程部署
4. 日志监控
