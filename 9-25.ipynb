# %%
import datetime

from util.util import importstr
from util.logconf import logging
log = logging.getLogger('nb')

# %%
def run(app, *argv):
    argv = list(argv)
    argv.insert(0, '--num-workers=8')  # <1>
    log.info("Running: {}({!r}).main()".format(app, argv))
    
    app_cls = importstr(*app.rsplit('.', 1))  # <2>
    app_cls(argv).main()
    
    log.info("Finished: {}.{!r}).main()".format(app, argv))

# %%
import os
import shutil

# clean up any old data that might be around.
# We don't call this by default because it's destructive, 
# and would waste a lot of time if it ran when nothing 
# on the application side had changed.
def cleanCache():
    shutil.rmtree('data-unversioned/cache')
    os.mkdir('data-unversioned/cache')

cleanCache()

# %%
training_epochs = 20
experiment_epochs = 10
final_epochs = 50

training_epochs = 2
experiment_epochs = 2
final_epochs = 5
seg_epochs = 10

# %%
run('code3.prepcache.LunaPrepCacheApp')
# Out:
# 2025-05-05 09:11:38,402 INFO     pid:8148 nb:004:run Running: code3.prepcache.LunaPrepCacheApp(['--num-workers=8']).main()
# 2025-05-05 09:11:41,850 INFO     pid:8148 code3.prepcache:048:main Starting LunaPrepCacheApp, Namespace(batch_size=1024, num_workers=8)
# 2025-05-05 09:11:45,586 WARNING  pid:8148 util.util:219:enumerateWithEstimate Stuffing cache ----/484, starting
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\1.work_vnpy\PyTorchMedicalImaging\9-25.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/1.work_vnpy/PyTorchMedicalImaging/9-25.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> run('code3.prepcache.LunaPrepCacheApp')
#
# f:\1.work_vnpy\PyTorchMedicalImaging\9-25.ipynb Cell 5 line 7
#       <a href='vscode-notebook-cell:/f%3A/1.work_vnpy/PyTorchMedicalImaging/9-25.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> log.info("Running: {}({!r}).main()".format(app, argv))
#       <a href='vscode-notebook-cell:/f%3A/1.work_vnpy/PyTorchMedicalImaging/9-25.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> app_cls = importstr(*app.rsplit('.', 1))  # <2>
# ----> <a href='vscode-notebook-cell:/f%3A/1.work_vnpy/PyTorchMedicalImaging/9-25.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> app_cls(argv).main()
#       <a href='vscode-notebook-cell:/f%3A/1.work_vnpy/PyTorchMedicalImaging/9-25.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> log.info("Finished: {}.{!r}).main()".format(app, argv))
#
# File f:\1.work_vnpy\PyTorchMedicalImaging\code3\prepcache.py:63, in LunaPrepCacheApp.main(self)
#      50 self.prep_dl = DataLoader(
#      51     PrepcacheLunaDataset(
#      52         # sortby_str='series_uid',
#    (...)
#      55     num_workers=self.cli_args.num_workers,
#      56 )
#      58 batch_iter = enumerateWithEstimate(
#      59     self.prep_dl,
#      60     "Stuffing cache",
#      61     start_ndx=self.prep_dl.num_workers,
#      62 )
# ---> 63 for batch_ndx, batch_tup in batch_iter:
#      64     pass
#
# File f:\1.work_vnpy\PyTorchMedicalImaging\util\util.py:224, in enumerateWithEstimate(iter, desc_str, start_ndx, print_ndx, backoff, iter_len)
#     219 log.warning("{} ----/{}, starting".format(
#     220     desc_str,
#     221     iter_len,
#     222 ))
#     223 start_ts = time.time()
# --> 224 for (current_ndx, item) in enumerate(iter):
#     225     yield (current_ndx, item)
#     226     if current_ndx == print_ndx:
#     227         # ... <1>
#
# File d:\ProgramData\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:735, in _BaseDataLoaderIter.__next__(self)
#     732 if self._sampler_iter is None:
#     733     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     734     self._reset()  # type: ignore[call-arg]
# --> 735 data = self._next_data()
#     736 self._num_yielded += 1
#     737 if (
#     738     self._dataset_kind == _DatasetKind.Iterable
#     739     and self._IterableDataset_len_called is not None
#     740     and self._num_yielded > self._IterableDataset_len_called
#     741 ):
#
# File d:\ProgramData\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:1517, in _MultiProcessingDataLoaderIter._next_data(self)
#    1515 worker_id = self._task_info.pop(idx)[0]
#    1516 self._rcvd_idx += 1
# -> 1517 return self._process_data(data, worker_id)
#
# File d:\ProgramData\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:1552, in _MultiProcessingDataLoaderIter._process_data(self, data, worker_idx)
#    1550 self._try_put_index()
#    1551 if isinstance(data, ExceptionWrapper):
# -> 1552     data.reraise()
#    1553 return data
#
# File d:\ProgramData\anaconda3\Lib\site-packages\torch\_utils.py:750, in ExceptionWrapper.reraise(self)
#     746 except Exception:
#     747     # If the exception takes multiple arguments or otherwise can't
#     748     # be constructed, don't try to instantiate since we don't know how to
#     749     raise RuntimeError(msg) from None
# --> 750 raise exception
#
# ValueError: Caught ValueError in DataLoader worker process 2.
# Original Traceback (most recent call last):
#   File "d:\ProgramData\anaconda3\Lib\site-packages\torch\utils\data\_utils\worker.py", line 349, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#            ^^^^^^^^^^^^^^^^^^^^
#   File "d:\ProgramData\anaconda3\Lib\site-packages\torch\utils\data\_utils\fetch.py", line 52, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "f:\1.work_vnpy\PyTorchMedicalImaging\code3\dsets.py", line 365, in __getitem__
#     getCtRawCandidate(candidateInfo_tup.series_uid, candidateInfo_tup.center_xyz, (7, 96, 96))
#   File "d:\ProgramData\anaconda3\Lib\site-packages\diskcache\core.py", line 1875, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "f:\1.work_vnpy\PyTorchMedicalImaging\code3\dsets.py", line 219, in getCtRawCandidate
#     ct = getCt(series_uid)
#          ^^^^^^^^^^^^^^^^^
#   File "f:\1.work_vnpy\PyTorchMedicalImaging\code3\dsets.py", line 215, in getCt
#     return Ct(series_uid)
#            ^^^^^^^^^^^^^^
#   File "f:\1.work_vnpy\PyTorchMedicalImaging\code3\dsets.py", line 105, in __init__
#     raise ValueError(f"No .mhd file found for series_uid: {series_uid}")
# ValueError: No .mhd file found for series_uid: 1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405

# %%
run('code3.training.SegmentationTrainingApp', f'--epochs={seg_epochs}', '--augmented', 'final-seg')
