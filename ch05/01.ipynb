# %%
import imageio

img_arr = imageio.imread('../data/2/horse1.jpg')
# Out:
# C:\Users\netstan\AppData\Local\Temp\ipykernel_26344\431682563.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_arr = imageio.imread('../data/2/horse1.jpg')

# %%
img_arr.shape
# Out:
# (426, 640, 3)

# %%
import torch
img = torch.from_numpy(img_arr)
out = img.permute(2,0,1)
out.shape
# Out:
# torch.Size([3, 426, 640])

# %%
out
# Out:
# tensor([[[218, 219, 219,  ...,  66,  66,  66],
#          [218, 219, 219,  ...,  66,  66,  66],
#          [219, 219, 220,  ...,  66,  66,  67],
#          ...,
#          [135, 138, 113,  ..., 207, 168, 170],
#          [163, 145, 129,  ..., 156, 170, 177],
#          [160, 130, 113,  ..., 153, 166, 172]],
#
#         [[220, 221, 221,  ..., 133, 133, 133],
#          [220, 221, 221,  ..., 133, 133, 133],
#          [221, 221, 222,  ..., 133, 133, 134],
#          ...,
#          [141, 144, 121,  ..., 204, 164, 166],
#          [166, 151, 135,  ..., 160, 174, 180],
#          [163, 133, 119,  ..., 165, 177, 184]],
#
#         [[217, 218, 218,  ..., 175, 175, 175],
#          [217, 218, 218,  ..., 175, 175, 175],
#          [216, 216, 217,  ..., 175, 175, 176],
#          ...,
#          [ 69,  72,  48,  ..., 135,  91,  92],
#          [ 97,  81,  65,  ...,  86,  98, 103],
#          [ 94,  64,  49,  ...,  89,  98, 102]]], dtype=torch.uint8)

# %%
batch_size = 3
batch = torch.zeros(batch_size, 3,256,256, dtype=torch.uint8)
import os

data_dir = '../data/3/cats'
filenames = [name for name in os.listdir(data_dir) if '.png' in name]

for i, filename in enumerate(filenames):
    img_arr = imageio.imread(os.path.join(data_dir, filename))
    img_t = torch.from_numpy(img_arr)
    img_t = img_t.permute(2,0,1)
    img_t = img_t[:3]
    batch[i] = img_t
# Out:
# C:\Users\netstan\AppData\Local\Temp\ipykernel_26344\221240406.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_arr = imageio.imread(os.path.join(data_dir, filename))

# %%
batch
# Out:
# tensor([[[[156, 152, 124,  ..., 150, 149, 158],
#           [174, 134, 165,  ..., 120, 136, 138],
#           [127, 156, 107,  ..., 131, 143, 164],
#           ...,
#           [116, 130, 129,  ..., 127, 118, 112],
#           [129, 130, 123,  ..., 115, 121, 114],
#           [129, 123, 118,  ..., 113, 121, 120]],
#
#          [[139, 135, 109,  ..., 135, 135, 147],
#           [160, 119, 149,  ..., 105, 122, 124],
#           [113, 140,  90,  ..., 118, 129, 152],
#           ...,
#           [ 99, 110, 111,  ..., 117, 108, 103],
#           [111, 111, 106,  ..., 106, 112, 105],
#           [111, 104, 102,  ..., 103, 110, 111]],
#
#          [[129, 123,  98,  ..., 131, 132, 145],
#           [155, 110, 137,  ..., 102, 119, 121],
#           [104, 132,  80,  ..., 112, 125, 146],
#           ...,
#           [ 93, 108, 105,  ..., 125, 115, 108],
#           [108, 108,  98,  ..., 110, 117, 110],
#           [107,  98,  95,  ..., 108, 115, 116]]],
#
#
#         [[[202, 193, 190,  ...,  13,  13,  12],
#           [199, 192, 189,  ...,  14,  14,  14],
#           [198, 193, 188,  ...,  12,  12,  12],
#           ...,
#           [ 93,  82,  76,  ...,  36,  36,  36],
#           [ 75,  68, 101,  ...,  36,  36,  37],
#           [ 85, 103,  90,  ...,  36,  37,  38]],
#
#          [[151, 139, 133,  ...,   9,   9,   8],
#           [151, 140, 134,  ...,  11,  11,  11],
#           [152, 143, 134,  ...,  11,  11,  11],
#           ...,
#           [ 57,  45,  39,  ...,  26,  26,  26],
#           [ 33,  26,  59,  ...,  26,  26,  27],
#           [ 40,  58,  45,  ...,  26,  27,  28]],
#
#          [[ 68,  53,  44,  ...,   6,   6,   5],
#           [ 67,  54,  44,  ...,   6,   6,   6],
#           [ 67,  56,  44,  ...,   6,   6,   6],
#           ...,
#           [ 31,  19,  12,  ...,  17,  17,  17],
#           [ 11,   2,  35,  ...,  17,  17,  18],
#           [ 19,  37,  22,  ...,  17,  18,  19]]],
#
#
#         [[[238, 238, 238,  ..., 214, 215, 215],
#           [238, 238, 238,  ..., 214, 215, 215],
#           [238, 238, 238,  ..., 214, 215, 215],
#           ...,
#           [214, 213, 212,  ..., 187, 190, 193],
#           [214, 213, 212,  ..., 186, 190, 192],
#           [214, 213, 212,  ..., 186, 190, 192]],
#
#          [[195, 195, 195,  ..., 173, 175, 175],
#           [195, 195, 195,  ..., 173, 175, 175],
#           [195, 195, 195,  ..., 173, 175, 175],
#           ...,
#           [128, 127, 126,  ..., 100, 103, 106],
#           [128, 127, 126,  ...,  99, 103, 105],
#           [128, 127, 126,  ...,  99, 103, 105]],
#
#          [[137, 137, 137,  ..., 125, 126, 126],
#           [137, 137, 137,  ..., 125, 126, 126],
#           [137, 137, 137,  ..., 125, 126, 126],
#           ...,
#           [ 79,  78,  77,  ...,  64,  68,  72],
#           [ 79,  78,  77,  ...,  64,  69,  71],
#           [ 79,  78,  77,  ...,  65,  69,  72]]]], dtype=torch.uint8)
